# %%
import requests
from bs4 import BeautifulSoup
import os
import re
import time

# --- Configuration ---
START_POPE_NAME = "Pius IV"
END_POPE_NAME = "John Paul II"
WIKIPEDIA_URL = "https://en.wikipedia.org/wiki/List_of_popes"
OUTPUT_FOLDER = "pope_images_indexed" # Changed folder name slightly
USER_AGENT = "PopeImageDownloader/1.1 (https://example.com/bot; myemail@example.com) PythonRequests/2.x"

# --- Helper Functions ---
def sanitize_filename(name):
    """Removes invalid characters for filenames and replaces spaces."""
    name = re.sub(r'[\\/*?:"<>|]', "", name)
    name = name.replace(" ", "_")
    return name

def get_full_image_url(thumb_url):
    """Converts a Wikipedia thumbnail URL to a full image URL."""
    if not thumb_url:
        return None
    if not thumb_url.startswith("//"):
        return None

    full_url = "https:" + thumb_url
    if "/thumb/" in full_url:
        parts = full_url.split('/')
        try:
            thumb_index = parts.index("thumb")
            image_path_segments = parts[thumb_index+1 : thumb_index+4]
            base_url_segments = parts[:thumb_index]
            full_image_url = "/".join(base_url_segments + image_path_segments)
            return full_image_url
        except (ValueError, IndexError) as e:
            print(f"    Could not parse thumbnail URL: {full_url} - {e}")
            return None
    return full_url

# --- Main Script ---
if __name__ == "__main__":
    if not os.path.exists(OUTPUT_FOLDER):
        os.makedirs(OUTPUT_FOLDER)

    print(f"Fetching popes list from {WIKIPEDIA_URL}...")
    headers = {'User-Agent': USER_AGENT}
    try:
        response = requests.get(WIKIPEDIA_URL, headers=headers)
        response.raise_for_status()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching URL: {e}")
        exit()

    soup = BeautifulSoup(response.content, 'html.parser')
    pope_tables = soup.find_all('table', class_='wikitable')

    if not pope_tables:
        print("No wikitable found. Wikipedia structure might have changed.")
        exit()

    found_start_pope = False
    download_count = 0
    file_index = 0 # Initialize file index for naming

    print(f"Searching for popes from {START_POPE_NAME} to {END_POPE_NAME}...")

    # Use 'break_all_loops' to exit outer loops when end pope is found
    break_all_loops = False

    for table in pope_tables:
        if break_all_loops:
            break
        rows = table.find_all('tr')
        for row in rows:
            cells = row.find_all('td')
            
            if len(cells) < 4:
                continue

            pope_name_tag = None
            pope_name_text = ""
            
            # Try cell index 3 (common for tables with portraits)
            name_cell_index = 3
            if len(cells) > name_cell_index:
                name_tag_container = cells[name_cell_index]
                bold_tag = name_tag_container.find('b')
                if bold_tag:
                    pope_name_tag = bold_tag.find('a')
                    if pope_name_tag:
                        pope_name_text = pope_name_tag.get_text(strip=True)
                    elif bold_tag.find(text=True, recursive=False):
                        pope_name_text = bold_tag.get_text(strip=True)
            
            # Fallback for tables where name might be in cell index 2
            if not pope_name_text and len(cells) > 2:
                name_cell_index = 2
                name_tag_container = cells[name_cell_index]
                bold_tag = name_tag_container.find('b')
                if bold_tag:
                    pope_name_tag = bold_tag.find('a')
                    if pope_name_tag:
                        pope_name_text = pope_name_tag.get_text(strip=True)
                    elif bold_tag.find(text=True, recursive=False):
                         pope_name_text = bold_tag.get_text(strip=True)

            pope_name_text_cleaned = re.sub(r"^(St |St\. |Bl |Bl\. |Ven\. |Servant of God )", "", pope_name_text)

            if not pope_name_text_cleaned:
                continue

            # --- Range Check ---
            if not found_start_pope and pope_name_text_cleaned == START_POPE_NAME:
                found_start_pope = True
                print(f"\nFound start pope: {pope_name_text_cleaned}")

            if not found_start_pope:
                continue
            
            # --- Pope is in range, increment index ---
            file_index += 1

            # --- Image Extraction ---
            image_url = None
            portrait_cell_index = 2 # Image is typically in cell index 2 for tables with portraits
            if len(cells) > portrait_cell_index:
                img_tag = cells[portrait_cell_index].find('img')
                if img_tag and img_tag.has_attr('src'):
                    thumbnail_src = img_tag['src']
                    image_url = get_full_image_url(thumbnail_src)

            if image_url:
                # Add index to the processing message
                print(f"  Processing ({file_index}): {pope_name_text_cleaned}")
                print(f"    Found image URL: {image_url}")
                
                # Prepend index to the filename
                filename = f"{file_index}_{sanitize_filename(pope_name_text_cleaned)}.jpg"
                filepath = os.path.join(OUTPUT_FOLDER, filename)

                try:
                    img_response = requests.get(image_url, headers=headers, stream=True)
                    img_response.raise_for_status()
                    with open(filepath, 'wb') as f:
                        for chunk in img_response.iter_content(chunk_size=8192):
                            f.write(chunk)
                    print(f"    Downloaded: {filepath}")
                    download_count += 1
                    time.sleep(0.5) 
                except requests.exceptions.RequestException as e:
                    print(f"    Error downloading image for {pope_name_text_cleaned}: {e}")
                except IOError as e:
                    print(f"    Error saving image {filepath}: {e}")
            else:
                # Add index to the message even if no image
                print(f"  Processing ({file_index}): {pope_name_text_cleaned} (No image found or URL parse failed)")

            if pope_name_text_cleaned == END_POPE_NAME:
                print(f"\nReached end pope: {pope_name_text_cleaned}. Stopping.")
                break_all_loops = True # Signal to break outer loop as well
                break # Stop processing rows in this table
        
    print(f"\nFinished. Downloaded {download_count} images to '{OUTPUT_FOLDER}'.")
# Out:
# Fetching popes list from https://en.wikipedia.org/wiki/List_of_popes...
# Searching for popes from Pius IV to John Paul II...
#
# Found start pope: Pius IV
#   Processing (1): Pius IV
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/b/be/Portrait_of_Pope_Pius_IV%2C_three-quarter-length%2C_seated_at_a_draped_table_%28Circle_of_Scipione_Pulzone%29.jpg
# /var/folders/fh/9thlgj7x52z2klhy0v7p470h0000gp/T/ipykernel_137/3590054885.py:106: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   elif bold_tag.find(text=True, recursive=False):
# /var/folders/fh/9thlgj7x52z2klhy0v7p470h0000gp/T/ipykernel_137/3590054885.py:94: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   elif bold_tag.find(text=True, recursive=False):
#     Downloaded: pope_images_indexed/1_Pius_IV.jpg
#   Processing (2): Pius V
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/2/28/Bartolomeo_Passarotti_-_Pius_V.jpg
#     Downloaded: pope_images_indexed/2_Pius_V.jpg
#   Processing (3): Gregory XIII
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/5/52/Pope_Gregory_XIII_portrait.jpg
#     Downloaded: pope_images_indexed/3_Gregory_XIII.jpg
#   Processing (4): Sixtus V
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/e/ed/Portrait_of_Pope_Sixtus_V.jpg
#     Downloaded: pope_images_indexed/4_Sixtus_V.jpg
#   Processing (5): Urban VII
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/e/ec/Papa_Urbano_VII_%28Pope_Urban_VII%29.jpg
#     Downloaded: pope_images_indexed/5_Urban_VII.jpg
#   Processing (6): Gregory XIV
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/f/f4/Roman_School_%E2%80%93_Portrait_of_Pope_Gregory_XIV_%2816th_Century%29.jpg
#     Downloaded: pope_images_indexed/6_Gregory_XIV.jpg
#   Processing (7): Innocent IX
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/3/32/Portrait_of_Pope_Innocent_IX_%28Fidenza_Cathedral_Museum_-_Museo_del_Duomo_di_Fidenza%2C_Fidenza%29.jpg
#     Downloaded: pope_images_indexed/7_Innocent_IX.jpg
#   Processing (8): Clement VIII
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/c/c9/Papst_Clemens_VIII_Italian_17th_century.jpg
#     Downloaded: pope_images_indexed/8_Clement_VIII.jpg
#   Processing (9): Leo XI
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/5/5d/Leo_XI_2.jpg
#     Downloaded: pope_images_indexed/9_Leo_XI.jpg
#   Processing (10): Paul V
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/4/4b/Pope_Paul_V_%28cropped_2%29.jpg
#     Downloaded: pope_images_indexed/10_Paul_V.jpg
#   Processing (11): Gregory XV
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/8/83/Pope_Gregory_XV.jpg
#     Downloaded: pope_images_indexed/11_Gregory_XV.jpg
#   Processing (12): Urban VIII
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/0/04/Urban_VIII_%28cropped%29.jpg
#     Downloaded: pope_images_indexed/12_Urban_VIII.jpg
#   Processing (13): Innocent X
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/7/7f/Retrato_del_Papa_Inocencio_X._Roma%2C_by_Diego_Vel%C3%A1zquez.jpg
#     Downloaded: pope_images_indexed/13_Innocent_X.jpg
#   Processing (14): Alexander VII
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/d/d1/Alexander_VII.jpg
#     Downloaded: pope_images_indexed/14_Alexander_VII.jpg
#   Processing (15): Clement IX
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/2/26/Portrait_of_Pope_Clement_IX%2C_by_Carlo_Maratti_%28or_Maratta%29_-_Hermitage_Museum.jpg
#     Downloaded: pope_images_indexed/15_Clement_IX.jpg
#   Processing (16): Clement X
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/7/74/Portrait_of_Pope_Clement_X%2C_by_Giovanni_Battista_Gaulli_%28Baciccio%29_-_Metropolitan_Museum_of_Art.jpg
#     Downloaded: pope_images_indexed/16_Clement_X.jpg
#   Processing (17): Innocent XI
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/f/f8/Jacob_Ferdinand_Voet_-_Portrait_of_Innocenzo_XI_Odescalchi_%28cropped%29.jpeg
#     Downloaded: pope_images_indexed/17_Innocent_XI.jpg
#   Processing (18): Alexander VIII
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/0/0e/Portrait_of_Pope_Alexander_VIII_%E2%80%93_Roman_School_of_17th_Century_%E2%80%93_%28unframed%29.jpg
#     Downloaded: pope_images_indexed/18_Alexander_VIII.jpg
#   Processing (19): Innocent XII
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/0/0c/Antonio_Zanchi_%E2%80%93_Papa_Innocenzo_XII_%28cropped%29.jpg
#     Downloaded: pope_images_indexed/19_Innocent_XII.jpg
#   Processing (20): Clement XI
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/6/62/Portrait_of_Pope_Clement_XI_Albani_%28Vatican_Museums_-_Musei_Vaticani%2C_Vatican%29.jpg
#     Downloaded: pope_images_indexed/20_Clement_XI.jpg
#   Processing (21): Innocent XIII
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/8/81/InnocientXIII.jpg
#     Downloaded: pope_images_indexed/21_Innocent_XIII.jpg
#   Processing (22): Benedict XIII
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/f/f7/Benedetto_XIII.jpg
#     Downloaded: pope_images_indexed/22_Benedict_XIII.jpg
#   Processing (23): Clement XII
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/c/cb/Agostino_Masucci_%E2%80%93_Portrait_of_Pope_Clement_XII%2C_seated.jpg
#     Downloaded: pope_images_indexed/23_Clement_XII.jpg
#   Processing (24): Benedict XIV
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/f/f9/Benoit_XIV.jpg
#     Downloaded: pope_images_indexed/24_Benedict_XIV.jpg
#   Processing (25): Clement XIII
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/8/8c/Anton_Raphael_Mengs_-_Portrait_of_pope_Clement_XIII%2C_c._1760.jpg
#     Downloaded: pope_images_indexed/25_Clement_XIII.jpg
#   Processing (26): Clement XIV
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/d/d6/Vincenzo_Milione_-_Portrait_of_Pope_Clement_XIV.jpg
#     Downloaded: pope_images_indexed/26_Clement_XIV.jpg
#   Processing (27): Pius VI
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/a/a2/Pompeo_Batoni_-_Ritratto_di_Papa_Pio_VI_%28National_Gallery_of_Ireland%29.jpg
#     Downloaded: pope_images_indexed/27_Pius_VI.jpg
#   Processing (28): Pius VII
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/4/4f/Jacques-Louis_David_018.jpg
#     Downloaded: pope_images_indexed/28_Pius_VII.jpg
#   Processing (29): Leo XII
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/6/6c/Charles_Picqu%C3%A9_%E2%80%93_Portrait_de_L%C3%A9on_XII_%281828%29.jpg
#     Downloaded: pope_images_indexed/29_Leo_XII.jpg
#   Processing (30): Pius VIII
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/7/7a/Ritratto_di_Papa_Pio_VIII%2C_by_Clemente_Alberi.jpg
#     Downloaded: pope_images_indexed/30_Pius_VIII.jpg
#   Processing (31): Gregory XVI
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/e/ef/Gregory_XVI.jpg
#     Downloaded: pope_images_indexed/31_Gregory_XVI.jpg
#   Processing (32): Pius IX
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/6/65/Pius_IX%2C_by_Adolphe_Braun%2C_1875.jpg
#     Downloaded: pope_images_indexed/32_Pius_IX.jpg
#   Processing (33): Leo XIII
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/8/83/Papa_Leone_XIII.jpeg
#     Downloaded: pope_images_indexed/33_Leo_XIII.jpg
#   Processing (34): Pius X
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/1/17/Pius_X%2C_by_Francesco_De_Federicis%2C_1903_%28cropped%29.jpg
#     Downloaded: pope_images_indexed/34_Pius_X.jpg
#   Processing (35): Benedict XV
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/0/0b/Benedictus_XV%2C_by_Nicola_Perscheid%2C_1915_%28retouched%29.jpg
#     Downloaded: pope_images_indexed/35_Benedict_XV.jpg
#   Processing (36): Pius XI
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/f/f9/Pius_XI%2C_by_Nicola_Perscheid_%28retouched%29.jpg
#     Downloaded: pope_images_indexed/36_Pius_XI.jpg
#   Processing (37): Pius XII
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/8/84/Pius_XII%2C_by_Michael_Pitcairn%2C_1951_%28cropped%29.jpg
#     Downloaded: pope_images_indexed/37_Pius_XII.jpg
#   Processing (38): John XXIII
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/0/0c/Ioannes_XXIII%2C_by_De_Agostini%2C_1958%E2%80%931963.jpg
#     Downloaded: pope_images_indexed/38_John_XXIII.jpg
#   Processing (39): Paul VI
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/b/b0/Paulus_VI%2C_by_Fotografia_Felici%2C_1969.jpg
#     Downloaded: pope_images_indexed/39_Paul_VI.jpg
#   Processing (40): John Paul I
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/e/e9/Paus_Johannes_Paulus_I_%28Bestanddeelnr_929-9074%29_%28cropped%29.jpg
#     Downloaded: pope_images_indexed/40_John_Paul_I.jpg
#   Processing (41): John Paul II
#     Found image URL: https://upload.wikimedia.org/wikipedia/commons/9/97/Pope_John_Paul_II_smile_FXD.jpg
#     Downloaded: pope_images_indexed/41_John_Paul_II.jpg
#
# Reached end pope: John Paul II. Stopping.
#
# Finished. Downloaded 41 images to 'pope_images_indexed'.
