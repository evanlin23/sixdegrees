# %%
import pandas as pd

# Read CSVs, replacing commas with dots for decimals
nodes_df = pd.read_csv('nodes.csv', sep=';', decimal=',')

# %%
print(nodes_df['Name'].tolist())
# Out:
# ['Alexander I of Yugoslavia', 'Aung San', 'Aung San Suu Kyi', 'Chow Yun-Fat', 'Claude Makélélé', 'Constans II', 'Dejan Savićević', 'François Bozizé', 'Jackie Chan', 'José Bosingwa', 'José Ramos-Horta', 'Joseph Kabila', "Léon M'ba", 'Leslie Cheung', 'Milo Đukanović', 'Mirko Vučinić', 'Mobutu Sese Seko', 'Mustafa III', 'Ne Win', 'Nick Drake', 'Niels Ryberg Finsen', 'Nikephoros I', 'Omar Bongo', 'Predrag Mijatović', 'Radovan Karadžić', 'Raymond Barre', 'Roland Garros', 'Stefan Nemanja', 'Stevan Jovetić', 'Steve Mandanda', 'Than Shwe', 'Thein Sein', 'Xanana Gusmão', 'Abdur Rahman Khan', 'Ahmed Shah Massoud', 'Jami', 'Mohammed Omar', 'Roxana', 'Zoroaster', 'Abbas I of Persia', 'Ahmed Shah Abdali', 'Amānullāh Khān', 'Burhanuddin Rabbani', 'Dost Mohammad Khan', 'Hafizullah Amin', 'Hamid Karzai', 'Humayun', 'Jamal al-Din al-Afghani', 'Khaled Hosseini', 'Mahmud of Ghazni', "Mir Ali Shir Nava'i", 'Mohammad Najibullah', 'Mohammed Daoud Khan', 'Mohammed Zahir Shah', 'Nur Muhammad Taraki', 'Ali Pasha', 'Anastasius I', 'Flavius Valerius Severus', 'Skanderbeg', 'Zog of Albania', 'Alfred Moisiu', 'Bamir Topi', 'Bujar Nishani', 'Enver Hoxha', 'Fatos Nano', 'Ismail Kadare', 'Masiela Lusha', 'Ramiz Alia', 'Rexhep Meidani', 'Sali Berisha', 'Sotiris Ninis', 'Ahmed Ouyahia', 'Apuleius', 'Augustine of Hippo', 'Chadli Bendjedid', 'Ferhat Abbas', 'Houari Boumédienne', 'Louis Althusser', 'Macrinus', 'Tariq ibn-Ziyad', 'Abd al-Qadir', 'Ahmed Ben Bella', 'Albert Camus', 'Assia Djebar', 'Claude Cohen-Tannoudji', 'Daniel Auteuil', 'Jacques Derrida', 'Monica of Hippo', 'Yves Saint-Laurent', 'Jaume Bartumeu', 'Agostinho Neto', 'Fernando da Piedade Dias dos Santos', 'Jonas Savimbi', 'José Eduardo dos Santos', 'Manucho Gonçalves', 'Baldwin Spencer', 'Adolfo Bioy Casares', 'Alberto Granado', 'Alfredo Di Stéfano', 'Ariel Ortega', 'Bérénice Bejo', 'Bernardo Houssay', 'César Milstein', 'César Pelli', 'Che Guevara', 'Claudio López', 'Daniel Barenboim', 'Eduardo Duhalde', 'Emiliano Insua', 'Éver Banega', 'Ezequiel Garay', 'Ezequiel Iván Lavezzi', 'Fernando de la Rúa', 'Gastón Gaudio', 'Gisela Dulko', 'Guillermo Cañas', 'Guillermo Coria', 'Guillermo Vilas', 'Hipólito Yrigoyen', 'Javier Pastore', 'Jonás Gutiérrez', 'Jorge Rafael Videla', 'Jorge Valdano', 'José de San Martín', 'Juan Mónaco', 'Leo Franco', 'Lisandro López', 'Lucas Barrios', 'Manu Ginóbili', 'Manuel Belgrano', 'Marcelo Bielsa', 'Maxi López', 'Mercedes Sosa', 'Nicolás Burdisso', 'Omar Sivori', 'Pablo Zabaleta', 'Princess Máxima of the Netherlands', 'Reynaldo Bignone', 'Roberto Abbondanzieri', 'Rodrigo Palacio', 'Sergio Romero', 'Walter Samuel', 'Carlos Menem', 'Adolfo Pérez Esquivel', 'Ángel Di María', 'Ástor Piazzolla', 'Carlos Saavedra Lamas', 'Carlos Tévez', 'Claudio Caniggia', 'Cristina Fernández de Kirchner', 'Daniel Passarella', 'David Nalbandian', 'Diego Maradona', 'Diego Milito', 'Ernesto Sabato', 'Esteban Cambiasso', 'Eva Perón', 'Fabricio Coloccini', 'Fernando Muslera', 'Fernando Redondo', 'Fernando Rubén Gago', 'Francisco Varallo', 'Gabriel Batistuta', 'Gabriel Heinze', 'Gabriel Milito', 'Gabriela Sabatini', 'Guillermo Stábile', 'Hernán Crespo', 'Isabel Martínez de Perón', 'Javier Mascherano', 'Javier Saviola', 'Javier Zanetti', 'Jorge Luis Borges', 'Juan Manuel de Rosas', 'Juan Manuel Fangio', 'Juan Martin Del Potro', 'Juan Pablo Sorín', 'Juan Perón', 'Juan Román Riquelme', 'Juan Sebastián Verón', 'Julio Ricardo Cruz', 'Leopoldo Galtieri', 'Lionel Messi', 'Luis González', 'Mario Kempes', 'Martha Argerich', 'Martin Demichelis', 'Martín Palermo', 'Mauro Camoranesi', 'Maximiliano Rodríguez', 'Néstor Kirchner', 'Nicolás Otamendi', 'Pablo Aimar', 'Raúl Alfonsín', 'Roberto Ayala', 'Sergio Agüero', 'Andranik Markaryan', 'Gregory the Illuminator', 'Levon Aronian', 'Philippikos', 'Saint Mesrob', 'Anastas Mikoyan', 'G. I. Gurdjieff', 'Shavo Odadjian', 'Tigran Sargsyan', 'シルショ', 'Bobby Farrell', 'Brett Emerton', 'Brett Holman', 'Casey Stoner', 'Cate Blanchett', 'Edmund Barton', 'Elizabeth Blackburn', 'El ...
